# %% [markdown]
# # Model Inference

# %% [markdown]
# ## Import Library

# %%
# import library
from tensorflow import keras
import pandas as pd
import numpy  as np
import joblib
from tensorflow.keras.models import load_model

# %% [markdown]
# # Data Loading

# %%
inf = pd.read_csv('inf.csv')
inf
# Out:
#             user_id  age gender region_category membership_category  \
# 0  b0c35c3d9e78c69e   40      F            Town     Gold Membership
# 1  94051ce85c2321f4   35      M            Town  Premium Membership
# 2  9f947b54bf56b353   58      M            Town       No Membership
# 3  9bcb8d62a974f700   28      M            City     Gold Membership
# 4  9b24e6181a0ef485   37      F            Town       No Membership
#
#    joining_date joined_through_referral     preferred_offer_types  \
# 0          2015                      No     Gift Vouchers/Coupons
# 1          2015                     Yes     Gift Vouchers/Coupons
# 2          2016                      No            Without Offers
# 3          2017                     Yes     Gift Vouchers/Coupons
# 4          2016                     Yes  Credit/Debit Card Offers
#
#   medium_of_operation internet_option  ...  avg_time_spent  \
# 0             Desktop     Mobile_Data  ...      815.797389
# ...

# %%
inf_final = inf.drop('churn_risk_score', axis=1)

# %%
inf_final
# Out:
#             user_id  age gender region_category membership_category  \
# 0  b0c35c3d9e78c69e   40      F            Town     Gold Membership
# 1  94051ce85c2321f4   35      M            Town  Premium Membership
# 2  9f947b54bf56b353   58      M            Town       No Membership
# 3  9bcb8d62a974f700   28      M            City     Gold Membership
# 4  9b24e6181a0ef485   37      F            Town       No Membership
#
#    joining_date joined_through_referral     preferred_offer_types  \
# 0          2015                      No     Gift Vouchers/Coupons
# 1          2015                     Yes     Gift Vouchers/Coupons
# 2          2016                      No            Without Offers
# 3          2017                     Yes     Gift Vouchers/Coupons
# 4          2016                     Yes  Credit/Debit Card Offers
#
#   medium_of_operation internet_option  ...  days_since_last_login  \
# 0             Desktop     Mobile_Data  ...                     10
# ...

# %% [markdown]
# # Model Loading

# %%
#load pipeline
pipeline = joblib.load(open('pipeline.pkl', 'rb'))

# %%
# load model
model = load_model('modelf_imp_wq5.h5')

# %%
dfinalnew = pipeline.transform(inf_final)
dfinalnew
# Out:
# array([[ 2.6648788 , -1.57107818,  0.60385962,  4.        ,  2.        ],
#        [-1.28623928, -0.06519719,  0.36360699,  2.        ,  2.        ],
#        [-0.22591138,  0.68774331, -0.07971367,  0.        ,  0.        ],
#        [-1.06884765, -0.06519719,  0.47516081,  4.        ,  0.        ],
#        [ 0.99742743,  0.14992867,  0.0327308 ,  0.        ,  1.        ]])

# %%
# predict result
predictions = model.predict(dfinalnew)
predictions = np.where(predictions>0.5,1,0)
predictions
# Out:
# 1/1 [==============================] - 0s 286ms/step
# array([[0],
#        [0],
#        [1],
#        [0],
#        [1]])

# %%
# show data infer + prediction
inf_final['churn_risk_score'] = predictions
inf_final
# Out:
#             user_id  age gender region_category membership_category  \
# 0  b0c35c3d9e78c69e   40      F            Town     Gold Membership
# 1  94051ce85c2321f4   35      M            Town  Premium Membership
# 2  9f947b54bf56b353   58      M            Town       No Membership
# 3  9bcb8d62a974f700   28      M            City     Gold Membership
# 4  9b24e6181a0ef485   37      F            Town       No Membership
#
#    joining_date joined_through_referral     preferred_offer_types  \
# 0          2015                      No     Gift Vouchers/Coupons
# 1          2015                     Yes     Gift Vouchers/Coupons
# 2          2016                      No            Without Offers
# 3          2017                     Yes     Gift Vouchers/Coupons
# 4          2016                     Yes  Credit/Debit Card Offers
#
#   medium_of_operation internet_option  ...  avg_time_spent  \
# 0             Desktop     Mobile_Data  ...      815.797389
# ...
